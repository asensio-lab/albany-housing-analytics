# %%
import pandas as pd

# %% [markdown]
# Tract 400, 2
# 501, 2
# 10, 2

# %%
PATH = '/Users/william/Dropbox (Amherst College)/CDS-2019-AlbanyHub/'

# %%
df = pd.read_csv(PATH + 'ToDatabase/TotalUtilities.csv')

# %%
water = df[df['Service Type'] == "RWTR"]

# %%
water[water['Consumption'] > 10000]
# Out:
#           ChargeID  Premise   Premise Address  Customer Service Type  \
# 6679932    6679932    41755  3701 WOODBURY RD  111137.0         RWTR
# 7504911    7504911    13843     333 S MOCK RD  206411.0         RWTR
# 8408459    8408459    75823    2503 DAYLOR CT   38577.0         RWTR
# 8593756    8593756  75823.0    2503 DAYLOR CT   38577.0         RWTR
# 14539033  14539033    13843     333 S MOCK RD  235015.0         RWTR
#
#           Service Number Service Rate  Consumption  Days of Service  \
# 6679932            300.0          140      10034.0             28.0
# 7504911            300.0          139      47241.0             34.0
# 8408459            300.0          130      21049.0             28.0
# 8593756            300.0          130      21102.0             34.0
# 14539033           300.0          139      11544.0             31.0
#
#          Unit of Measure  Charge Amount Charge Date  Year  Month  Day  \
# ...

# %%
water['Unit of Measure'].value_counts()
# Out:
# TGAL    2630643
# Name: Unit of Measure, dtype: int64

# %%
water['Charge Amount'].describe()
# Out:
# count    2.630643e+06
# mean     2.006524e+01
# std      1.003457e+02
# min     -1.865640e+03
# 25%      1.106000e+01
# 50%      1.345000e+01
# 75%      2.050000e+01
# max      8.648098e+04
# Name: Charge Amount, dtype: float64

# %%
pd.options.display.max_rows = 1000

# %%
water[water['Premise Address'].str.contains("333 S MOCK RD")]
# Out:
#           ChargeID  Premise Premise Address  Customer Service Type  \
# 10675        10675    13843   333 S MOCK RD   53434.0         RWTR
# 11205        11205    14127   333 S MOCK RD   53434.0         RWTR
# 174623      174623    13843   333 S MOCK RD   53434.0         RWTR
# 175148      175148    14127   333 S MOCK RD   53434.0         RWTR
# 341829      341829    13843   333 S MOCK RD   53434.0         RWTR
# 342341      342341    14127   333 S MOCK RD   53434.0         RWTR
# 507996      507996    13843   333 S MOCK RD   53434.0         RWTR
# 508523      508523    14127   333 S MOCK RD   53434.0         RWTR
# 674549      674549    13843   333 S MOCK RD   53434.0         RWTR
# 675090      675090    14127   333 S MOCK RD   53434.0         RWTR
# 841798      841798    13843   333 S MOCK RD   53434.0         RWTR
# 842341      842341    14127   333 S MOCK RD   53434.0         RWTR
# 1008927    1008927    13843   333 S MOCK RD   53434.0         RWTR
# ...

# %%
water[water['Charge Amount'] > 10000]
# Out:
#           ChargeID  Premise       Premise Address  Customer Service Type  \
# 1115212    1115212    42336  4000 GILLIONVILLE RD   42174.0         RWTR
# 7398802    7398802    33413         2609 FLYNN CT  208751.0         RWTR
# 7504909    7504909    13843         333 S MOCK RD  206411.0         RWTR
# 8248669    8248669    14282       1511 WHITING DR  118220.0         RWTR
# 8593754    8593754  75823.0        2503 DAYLOR CT   38577.0         RWTR
# 9053810    9053810    31433     1200 KINGSTOWN CT   66010.0         RWTR
# 11772120  11772120    33353    2220 FRIAR TUCK LN  226251.0         RWTR
# 12057707  12057707  13843.0         333 S MOCK RD  206411.0         RWTR
# 14063829  14063829    43709     636 W SOCIETY AVE   22703.0         RWTR
# 14078327  14078327    44980        905 N DAVIS ST   28608.0         RWTR
# 14339915  14339915    44980        905 N DAVIS ST   28608.0         RWTR
# 14539032  14539032    13843         333 S MOCK RD  235015.0         RWTR
#
# ...

# %%
water[water['Charge Amount'] > 86000]
# Out:
#           ChargeID  Premise Premise Address  Customer Service Type  \
# 12057707  12057707  13843.0   333 S MOCK RD  206411.0         RWTR
#
#           Service Number Service Rate  Consumption  Days of Service  \
# 12057707           300.0          NaN          NaN              NaN
#
#          Unit of Measure  Charge Amount Charge Date  Year  Month  Day  \
# 12057707            TGAL       86480.98  2018-01-09  2018      1    9
#
#           PrimaryID
# 12057707      30002

# %%
df_400_2 = pd.read_csv(PATH + "Raw-Data/water_investigate/rwtr_high_values_400_2.csv")
df_400_2_housing = pd.read_csv(PATH + "Raw-Data/water_investigate/rwtr_high_values_400_2_housing.csv")
df_501_2 = pd.read_csv(PATH + "Raw-Data/water_investigate/rwtr_high_values_501_2.csv")
df_501_2_housing = pd.read_csv(PATH + "Raw-Data/water_investigate/rwtr_high_values_501_2_housing.csv")
df_1000_2 = pd.read_csv(PATH + "Raw-Data/water_investigate/rwtr_high_values_1000_2.csv")
df_1000_2_housing = pd.read_csv(PATH + "Raw-Data/water_investigate/rwtr_high_values_1000_2_housing.csv")

# %%
print(df_400_2['Consumption'].sum() / df_400_2.shape[0])
print(df_400_2_housing['Consumption'].sum() / df_400_2_housing.shape[0])
# Out:
# 7.965987305946779
