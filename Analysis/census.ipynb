# %%
import pandas as pd

# %%
block_group = pd.read_csv('/Users/davidreynolds/Dropbox/CDS-2019-AlbanyHub/ToDatabase/full_blockgroup.csv')
tract = pd.read_csv('/Users/davidreynolds/Dropbox/CDS-2019-AlbanyHub/ToDatabase/full_tract.csv')

# %%
block_group = block_group[block_group.county == 'Dougherty County']
block_group = block_group.drop(['geo_id', 'geo_id2', 'county', 'block_tract'], axis = 1)

# %%
block_group['inc_less_19999k'] = block_group['inc_less_10k'] + block_group['inc_10k_14999'] + block_group['inc_15k_19999']

# %%
block_group
# Out:
#     block_group  tract  total_pop  total_inc  inc_less_10k  inc_10k_14999  \
# 4             1    100        669        280             0              0
# 5             2    100        461        175            16             32
# 6             3    100        933        329           121              0
# 7             4    100       1444        714           135             51
# 8             5    100        959        407            90             37
# 9             1    200        717        271            87             21
# 10            2    200        167        101             8              9
# 11            3    200       1561        470            79            111
# 12            4    200        609        164            77              9
# 13            1    400       1293        575            65             51
# 14            2    400       2099        823           196             23
# 15            3    400       2727       1388            59            131
# ...
