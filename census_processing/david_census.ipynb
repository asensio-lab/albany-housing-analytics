# %%
import pandas as pd
from pandas import DataFrame
import re

# %%
vacancy = pd.read_csv('~/Dropbox/CDS-2019-AlbanyHub/Census/vacancy_17.csv')
owner_renter = pd.read_csv('~/Dropbox/CDS-2019-AlbanyHub/Census/owner_renter_17.csv')
employment = pd.read_csv('~/Dropbox/CDS-2019-AlbanyHub/Census/employment_17.csv')

# %%
vacancy
# Out:
#                     GEO.id       GEO.id2  \
# 0                       Id           Id2
# 1    1500000US130079601001  130079601001
# 2    1500000US130079601002  130079601002
# 3    1500000US130079602001  130079602001
# 4    1500000US130079602002  130079602002
# 5    1500000US130950001001  130950001001
# 6    1500000US130950001002  130950001002
# 7    1500000US130950001003  130950001003
# 8    1500000US130950001004  130950001004
# 9    1500000US130950001005  130950001005
# 10   1500000US130950002001  130950002001
# 11   1500000US130950002002  130950002002
# 12   1500000US130950002003  130950002003
# 13   1500000US130950002004  130950002004
# 14   1500000US130950004001  130950004001
# 15   1500000US130950004002  130950004002
# 16   1500000US130950004003  130950004003
# 17   1500000US130950005011  130950005011
# 18   1500000US130950005012  130950005012
# 19   1500000US130950005021  130950005021
# 20   1500000US130950005022  130950005022
# 21   1500000US130950005023  130950005023
# 22   1500000US130950005024  130950005024
# 23   1500000US130950006001  130950006001
# 24   1500000US130950006002  130950006002
# 25   1500000US130950007001  130950007001
# 26   1500000US130950008001  130950008001
# 27   1500000US130950008002  130950008002
# 28   1500000US130950009001  130950009001
# 29   1500000US130950009002  130950009002
# ..                     ...           ...
# 82   1500000US131770204022  131770204022
# 83   1500000US131770204023  131770204023
# 84   1500000US131770204024  131770204024
# 85   1500000US131770204031  131770204031
# 86   1500000US131770204032  131770204032
# 87   1500000US132731202001  132731202001
# 88   1500000US132731202002  132731202002
# 89   1500000US132731203001  132731203001
# 90   1500000US132731203002  132731203002
# 91   1500000US132731203003  132731203003
# 92   1500000US132731203004  132731203004
# 93   1500000US132731204001  132731204001
# 94   1500000US132731204002  132731204002
# 95   1500000US132731204003  132731204003
# 96   1500000US132731205001  132731205001
# 97   1500000US133219501001  133219501001
# 98   1500000US133219501002  133219501002
# 99   1500000US133219502001  133219502001
# 100  1500000US133219502002  133219502002
# 101  1500000US133219502003  133219502003
# 102  1500000US133219502004  133219502004
# 103  1500000US133219504001  133219504001
# 104  1500000US133219504002  133219504002
# 105  1500000US133219504003  133219504003
# 106  1500000US133219504004  133219504004
# 107  1500000US133219505001  133219505001
# 108  1500000US133219505002  133219505002
# 109  1500000US133219505003  133219505003
# 110  1500000US133219506001  133219506001
# 111  1500000US133219506002  133219506002
#
#                                      GEO.display-label         HD01_VD01  \
# 0                                            Geography  Estimate; Total:
# 1    Block Group 1, Census Tract 9601, Baker County...               524
# 2    Block Group 2, Census Tract 9601, Baker County...               595
# 3    Block Group 1, Census Tract 9602, Baker County...               298
# 4    Block Group 2, Census Tract 9602, Baker County...               353
# 5    Block Group 1, Census Tract 1, Dougherty Count...               433
# 6    Block Group 2, Census Tract 1, Dougherty Count...               175
# 7    Block Group 3, Census Tract 1, Dougherty Count...               397
# 8    Block Group 4, Census Tract 1, Dougherty Count...               938
# 9    Block Group 5, Census Tract 1, Dougherty Count...               493
# 10   Block Group 1, Census Tract 2, Dougherty Count...               352
# 11   Block Group 2, Census Tract 2, Dougherty Count...               170
# 12   Block Group 3, Census Tract 2, Dougherty Count...               560
# 13   Block Group 4, Census Tract 2, Dougherty Count...               244
# 14   Block Group 1, Census Tract 4, Dougherty Count...               738
# 15   Block Group 2, Census Tract 4, Dougherty Count...              1027
# 16   Block Group 3, Census Tract 4, Dougherty Count...              1542
# 17   Block Group 1, Census Tract 5.01, Dougherty Co...              1476
# 18   Block Group 2, Census Tract 5.01, Dougherty Co...               880
# 19   Block Group 1, Census Tract 5.02, Dougherty Co...               668
# 20   Block Group 2, Census Tract 5.02, Dougherty Co...               550
# 21   Block Group 3, Census Tract 5.02, Dougherty Co...               237
# 22   Block Group 4, Census Tract 5.02, Dougherty Co...               485
# 23   Block Group 1, Census Tract 6, Dougherty Count...               713
# 24   Block Group 2, Census Tract 6, Dougherty Count...               799
# 25   Block Group 1, Census Tract 7, Dougherty Count...               933
# 26   Block Group 1, Census Tract 8, Dougherty Count...               428
# 27   Block Group 2, Census Tract 8, Dougherty Count...               298
# 28   Block Group 1, Census Tract 9, Dougherty Count...               543
# 29   Block Group 2, Census Tract 9, Dougherty Count...               551
# ..                                                 ...               ...
# 82   Block Group 2, Census Tract 204.02, Lee County...              1478
# 83   Block Group 3, Census Tract 204.02, Lee County...               447
# 84   Block Group 4, Census Tract 204.02, Lee County...               464
# 85   Block Group 1, Census Tract 204.03, Lee County...              1888
# 86   Block Group 2, Census Tract 204.03, Lee County...               300
# 87   Block Group 1, Census Tract 1202, Terrell Coun...               287
# 88   Block Group 2, Census Tract 1202, Terrell Coun...               491
# 89   Block Group 1, Census Tract 1203, Terrell Coun...               354
# 90   Block Group 2, Census Tract 1203, Terrell Coun...               558
# 91   Block Group 3, Census Tract 1203, Terrell Coun...               271
# 92   Block Group 4, Census Tract 1203, Terrell Coun...               291
# 93   Block Group 1, Census Tract 1204, Terrell Coun...               489
# 94   Block Group 2, Census Tract 1204, Terrell Coun...               320
# 95   Block Group 3, Census Tract 1204, Terrell Coun...               465
# 96   Block Group 1, Census Tract 1205, Terrell Coun...               651
# 97   Block Group 1, Census Tract 9501, Worth County...               664
# 98   Block Group 2, Census Tract 9501, Worth County...               766
# 99   Block Group 1, Census Tract 9502, Worth County...               638
# 100  Block Group 2, Census Tract 9502, Worth County...               935
# 101  Block Group 3, Census Tract 9502, Worth County...               632
# 102  Block Group 4, Census Tract 9502, Worth County...               707
# 103  Block Group 1, Census Tract 9504, Worth County...               733
# 104  Block Group 2, Census Tract 9504, Worth County...               378
# 105  Block Group 3, Census Tract 9504, Worth County...               304
# 106  Block Group 4, Census Tract 9504, Worth County...               549
# 107  Block Group 1, Census Tract 9505, Worth County...               925
# 108  Block Group 2, Census Tract 9505, Worth County...               510
# 109  Block Group 3, Census Tract 9505, Worth County...               565
# 110  Block Group 1, Census Tract 9506, Worth County...               590
# 111  Block Group 2, Census Tract 9506, Worth County...               420
#
#                    HD02_VD01                    HD01_VD02  \
# 0    Margin of Error; Total:  Estimate; Total: - Occupied
# 1                         91                          378
# 2                         94                          426
# 3                         65                          224
# 4                         69                          293
# 5                        129                          280
# 6                         98                          175
# 7                        132                          329
# 8                        194                          714
# 9                        127                          407
# 10                       102                          271
# 11                        78                          101
# 12                       118                          470
# 13                        84                          164
# 14                       176                          575
# 15                       177                          823
# 16                       195                         1388
# 17                       173                         1412
# 18                       146                          869
# 19                       114                          609
# 20                       101                          522
# 21                        54                          237
# 22                        73                          443
# 23                       107                          583
# 24                       111                          606
# 25                        50                          761
# 26                        60                          353
# 27                        68                          209
# 28                        73                          413
# 29                        65                          425
# ..                       ...                          ...
# 82                       226                         1478
# 83                       139                          367
# 84                        86                          464
# 85                       134                         1851
# 86                        78                          274
# 87                        53                          217
# 88                        59                          338
# 89                        93                          294
# 90                       120                          426
# 91                        94                          173
# 92                        76                          204
# 93                       100                          428
# 94                        70                          320
# 95                       105                          313
# 96                        63                          577
# 97                       111                          459
# 98                       110                          656
# 99                       146                          638
# 100                      169                          799
# 101                      170                          585
# 102                      204                          661
# 103                      124                          616
# 104                      106                          262
# 105                       76                          255
# 106                      103                          440
# 107                      143                          695
# 108                      119                          487
# 109                      131                          492
# 110                       75                          542
# 111                       72                          312
#
#                               HD02_VD02                  HD01_VD03  \
# 0    Margin of Error; Total: - Occupied  Estimate; Total: - Vacant
# 1                                    77                        146
# 2                                    71                        169
# 3                                    63                         74
# 4                                    64                         60
# 5                                   124                        153
# 6                                    98                          0
# 7                                   118                         68
# 8                                   180                        224
# 9                                   140                         86
# 10                                  107                         81
# 11                                   65                         69
# 12                                  119                         90
# 13                                   69                         80
# 14                                  155                        163
# 15                                  172                        204
# 16                                  194                        154
# 17                                  186                         64
# 18                                  149                         11
# 19                                  119                         59
# 20                                  107                         28
# 21                                   54                          0
# 22                                   72                         42
# 23                                  107                        130
# 24                                  136                        193
# 25                                   70                        172
# 26                                   64                         75
# 27                                   66                         89
# 28                                   74                        130
# 29                                   61                        126
# ..                                  ...                        ...
# 82                                  226                          0
# 83                                  130                         80
# 84                                   86                          0
# 85                                  137                         37
# 86                                   70                         26
# 87                                   47                         70
# 88                                   57                        153
# 89                                   73                         60
# 90                                  103                        132
# 91                                   59                         98
# 92                                   71                         87
# 93                                   94                         61
# 94                                   70                          0
# 95                                   72                        152
# 96                                   64                         74
# 97                                  113                        205
# 98                                  115                        110
# 99                                  146                          0
# 100                                 171                        136
# 101                                 166                         47
# 102                                 199                         46
# 103                                 120                        117
# 104                                  84                        116
# 105                                  65                         49
# 106                                  82                        109
# 107                                 126                        230
# 108                                 111                         23
# 109                                 132                         73
# 110                                  76                         48
# 111                                  62                        108
#
#                             HD02_VD03
# 0    Margin of Error; Total: - Vacant
# 1                                  58
# 2                                  68
# 3                                  47
# 4                                  40
# 5                                 102
# 6                                  13
# 7                                  75
# 8                                 131
# 9                                  62
# 10                                 64
# 11                                 62
# 12                                 63
# 13                                 62
# 14                                103
# 15                                125
# 16                                111
# 17                                 70
# 18                                 19
# 19                                 63
# 20                                 34
# 21                                 13
# 22                                 44
# 23                                 90
# 24                                100
# 25                                 57
# 26                                 35
# 27                                 39
# 28                                 55
# 29                                 51
# ..                                ...
# 82                                 13
# 83                                 88
# 84                                 13
# 85                                 46
# 86                                 42
# 87                                 35
# 88                                 50
# 89                                 68
# 90                                 89
# 91                                 90
# 92                                 71
# 93                                 58
# 94                                 13
# 95                                 82
# 96                                 35
# 97                                 89
# 98                                 76
# 99                                 13
# 100                               117
# 101                                72
# 102                                67
# 103                                50
# 104                                80
# 105                                55
# 106                                64
# 107                                97
# 108                                39
# 109                                55
# 110                                37
# 111                                55
#
# [112 rows x 9 columns]

# %%
owner_renter.head()
# Out:
#                   GEO.id       GEO.id2  \
# 0                     Id           Id2
# 1  1500000US130079601001  130079601001
# 2  1500000US130079601002  130079601002
# 3  1500000US130079602001  130079602001
# 4  1500000US130079602002  130079602002
#
#                                    GEO.display-label         HD01_VD01  \
# 0                                          Geography  Estimate; Total:
# 1  Block Group 1, Census Tract 9601, Baker County...               869
# 2  Block Group 2, Census Tract 9601, Baker County...              1247
# 3  Block Group 1, Census Tract 9602, Baker County...               487
# 4  Block Group 2, Census Tract 9602, Baker County...               645
#
#                  HD02_VD01                          HD01_VD02  \
# 0  Margin of Error; Total:  Estimate; Total: - Owner occupied
# 1                      181                                457
# 2                      223                                764
# 3                      149                                386
# 4                      120                                489
#
#                                   HD02_VD02  \
# 0  Margin of Error; Total: - Owner occupied
# 1                                       159
# 2                                       170
# 3                                       133
# 4                                       120
#
#                             HD01_VD03  \
# 0  Estimate; Total: - Renter occupied
# 1                                 412
# 2                                 483
# 3                                 101
# 4                                 156
#
#                                    HD02_VD03
# 0  Margin of Error; Total: - Renter occupied
# 1                                        154
# 2                                        210
# 3                                         74
# 4                                         91

# %%
employment.head()
# Out:
#                   GEO.id       GEO.id2  \
# 0                     Id           Id2
# 1  1500000US130079601001  130079601001
# 2  1500000US130079601002  130079601002
# 3  1500000US130079602001  130079602001
# 4  1500000US130079602002  130079602002
#
#                                    GEO.display-label         HD01_VD01  \
# 0                                          Geography  Estimate; Total:
# 1  Block Group 1, Census Tract 9601, Baker County...               684
# 2  Block Group 2, Census Tract 9601, Baker County...              1038
# 3  Block Group 1, Census Tract 9602, Baker County...               450
# 4  Block Group 2, Census Tract 9602, Baker County...               507
#
#                  HD02_VD01                  HD01_VD02  \
# 0  Margin of Error; Total:  Estimate; In labor force:
# 1                      144                        350
# 2                      170                        488
# 3                      129                        262
# 4                       98                        219
#
#                           HD02_VD02  \
# 0  Margin of Error; In labor force:
# 1                               113
# 2                               124
# 3                               106
# 4                                69
#
#                                            HD01_VD03  \
# 0  Estimate; In labor force: - Civilian labor force:
# 1                                                350
# 2                                                488
# 3                                                262
# 4                                                219
#
#                                            HD02_VD03  \
# 0  Margin of Error; In labor force: - Civilian la...
# 1                                                113
# 2                                                124
# 3                                                106
# 4                                                 69
#
#                                            HD01_VD04  \
# 0  Estimate; In labor force: - Civilian labor for...
# 1                                                350
# 2                                                461
# 3                                                262
# 4                                                213
#
#                                            HD02_VD04  \
# 0  Margin of Error; In labor force: - Civilian la...
# 1                                                113
# 2                                                126
# 3                                                106
# 4                                                 69
#
#                                            HD01_VD05  \
# 0  Estimate; In labor force: - Civilian labor for...
# 1                                                  0
# 2                                                 27
# 3                                                  0
# 4                                                  6
#
#                                            HD02_VD05  \
# 0  Margin of Error; In labor force: - Civilian la...
# 1                                                 13
# 2                                                 22
# 3                                                 13
# 4                                                  9
#
#                                   HD01_VD06  \
# 0  Estimate; In labor force: - Armed Forces
# 1                                         0
# 2                                         0
# 3                                         0
# 4                                         0
#
#                                          HD02_VD06  \
# 0  Margin of Error; In labor force: - Armed Forces
# 1                                               13
# 2                                               13
# 3                                               13
# 4                                               13
#
#                       HD01_VD07                            HD02_VD07
# 0  Estimate; Not in labor force  Margin of Error; Not in labor force
# 1                           334                                   87
# 2                           550                                  156
# 3                           188                                   70
# 4                           288                                   81

# %% [markdown]
# # vacancy

# %%
new = vacancy["GEO.display-label"].str.split(", ", expand = True)   
vacancy["block"] = new[0] 
vacancy["tract"] = new[1]
vacancy["county"] = new[2]

# %%
vacancy = vacancy.drop('GEO.display-label', axis = 1)

# %%
l = len(vacancy['tract'])
vacancy1 = vacancy.copy()
re_string = 'Census Tract (\d+(?:.\d+)?)'
for i in range(1,l):
    s = vacancy.loc[i, 'tract']
    m = re.search(re_string, s)
    vacancy1.loc[i, 'tract'] = m.group(1)

# %%
l = len(vacancy['block'])
re_string = 'Block Group (\d+(?:.\d+)?)'
for i in range(1,l):
    s = vacancy.loc[i, 'block']
    m = re.search(re_string, s)
    vacancy1.loc[i, 'block'] = m.group(1)

# %%
tract_series = vacancy1['tract']
l = len(vacancy1['tract'])
for i in range(1,l):
    if '.' in tract_series[i]:
        s = tract_series[i].split('.')
        if len(s[0]) == 1:
            tract_series[i] = s[0] + s[1]
        elif len(s[0]) == 2:
            tract_series[i] = s[0] + s[1]
        elif len(s[0]) == 3:
            tract_series[i] = s[0] + s[1]
    else:
        if len(tract_series[i]) == 3:
            tract_series[i] = vacancy1['tract'][i] + '00'
        elif len(tract_series[i]) == 2:
            tract_series[i] = vacancy1['tract'][i] + '00'
        elif len(tract_series[i]) == 1:
            tract_series[i] = vacancy1['tract'][i] + '00'
        elif len(tract_series[i]) == 4:
            tract_series[i] = vacancy1['tract'][i] + '00'

# %%
vacancy1.head()
vacancy1.shape
# Out:
# (112, 11)

# %% [markdown]
# # owner_renter

# %%
new = owner_renter["GEO.display-label"].str.split(", ", expand = True)   
owner_renter["block"] = new[0] 
owner_renter["tract"] = new[1]
owner_renter["county"] = new[2]

# %%
owner_renter = owner_renter.drop('GEO.display-label', axis = 1)

# %%
l = len(owner_renter['tract'])
owner_renter1 = owner_renter.copy()
re_string = 'Census Tract (\d+(?:.\d+)?)'
for i in range(1,l):
    s = owner_renter.loc[i, 'tract']
    m = re.search(re_string, s)
    owner_renter1.loc[i, 'tract'] = m.group(1)

# %%
l = len(owner_renter['block'])
re_string = 'Block Group (\d+(?:.\d+)?)'
for i in range(1,l):
    s = owner_renter.loc[i, 'block']
    m = re.search(re_string, s)
    owner_renter1.loc[i, 'block'] = m.group(1)

# %%
tract_series = owner_renter1['tract']
l = len(owner_renter1['tract'])
for i in range(1,l):
    if '.' in tract_series[i]:
        s = tract_series[i].split('.')
        if len(s[0]) == 1:
            tract_series[i] = s[0] + s[1]
        elif len(s[0]) == 2:
            tract_series[i] = s[0] + s[1]
        elif len(s[0]) == 3:
            tract_series[i] = s[0] + s[1]
    else:
        if len(tract_series[i]) == 3:
            tract_series[i] = owner_renter1['tract'][i] + '00'
        elif len(tract_series[i]) == 2:
            tract_series[i] = owner_renter1['tract'][i] + '00'
        elif len(tract_series[i]) == 1:
            tract_series[i] = owner_renter1['tract'][i] + '00'
        elif len(tract_series[i]) == 4:
            tract_series[i] = owner_renter1['tract'][i] + '00'

# %%
owner_renter1.head()
#owner_renter1.shape
# Out:
#                   GEO.id       GEO.id2         HD01_VD01  \
# 0                     Id           Id2  Estimate; Total:
# 1  1500000US130079601001  130079601001               869
# 2  1500000US130079601002  130079601002              1247
# 3  1500000US130079602001  130079602001               487
# 4  1500000US130079602002  130079602002               645
#
#                  HD02_VD01                          HD01_VD02  \
# 0  Margin of Error; Total:  Estimate; Total: - Owner occupied
# 1                      181                                457
# 2                      223                                764
# 3                      149                                386
# 4                      120                                489
#
#                                   HD02_VD02  \
# 0  Margin of Error; Total: - Owner occupied
# 1                                       159
# 2                                       170
# 3                                       133
# 4                                       120
#
#                             HD01_VD03  \
# 0  Estimate; Total: - Renter occupied
# 1                                 412
# 2                                 483
# 3                                 101
# 4                                 156
#
#                                    HD02_VD03      block   tract        county
# 0  Margin of Error; Total: - Renter occupied  Geography    None          None
# 1                                        154          1  960100  Baker County
# 2                                        210          2  960100  Baker County
# 3                                         74          1  960200  Baker County
# 4                                         91          2  960200  Baker County

# %% [markdown]
# # employment

# %%
new = employment["GEO.display-label"].str.split(", ", expand = True)   
employment["block"] = new[0] 
employment["tract"] = new[1]
employment["county"] = new[2]

# %%
employment = employment.drop('GEO.display-label', axis = 1)

# %%
l = len(employment['tract'])
employment1 = employment.copy()
re_string = 'Census Tract (\d+(?:.\d+)?)'
for i in range(1,l):
    s = employment.loc[i, 'tract']
    m = re.search(re_string, s)
    employment1.loc[i, 'tract'] = m.group(1)

# %%
l = len(employment['block'])
re_string = 'Block Group (\d+(?:.\d+)?)'
for i in range(1,l):
    s = employment.loc[i, 'block']
    m = re.search(re_string, s)
    employment1.loc[i, 'block'] = m.group(1)

# %%
tract_series = employment1['tract']
l = len(employment1['tract'])
for i in range(1,l):
    if '.' in tract_series[i]:
        s = tract_series[i].split('.')
        if len(s[0]) == 1:
            tract_series[i] = s[0] + s[1]
        elif len(s[0]) == 2:
            tract_series[i] = s[0] + s[1]
        elif len(s[0]) == 3:
            tract_series[i] = s[0] + s[1]
    else:
        if len(tract_series[i]) == 3:
            tract_series[i] = employment1['tract'][i] + '00'
        elif len(tract_series[i]) == 2:
            tract_series[i] = employment1['tract'][i] + '00'
        elif len(tract_series[i]) == 1:
            tract_series[i] = employment1['tract'][i] + '00'
        elif len(tract_series[i]) == 4:
            tract_series[i] = employment1['tract'][i] + '00'

# %%
employment1.head()
employment1.shape
# Out:
# (112, 19)

# %% [markdown]
# # Merging

# %%
vacancy1['block_tract'] = vacancy1['block'] + '_' + vacancy1['tract']
vacancy1.head()
# Out:
#                   GEO.id       GEO.id2         HD01_VD01  \
# 0                     Id           Id2  Estimate; Total:
# 1  1500000US130079601001  130079601001               524
# 2  1500000US130079601002  130079601002               595
# 3  1500000US130079602001  130079602001               298
# 4  1500000US130079602002  130079602002               353
#
#                  HD02_VD01                    HD01_VD02  \
# 0  Margin of Error; Total:  Estimate; Total: - Occupied
# 1                       91                          378
# 2                       94                          426
# 3                       65                          224
# 4                       69                          293
#
#                             HD02_VD02                  HD01_VD03  \
# 0  Margin of Error; Total: - Occupied  Estimate; Total: - Vacant
# 1                                  77                        146
# 2                                  71                        169
# 3                                  63                         74
# 4                                  64                         60
#
#                           HD02_VD03      block   tract        county  \
# 0  Margin of Error; Total: - Vacant  Geography    None          None
# 1                                58          1  960100  Baker County
# 2                                68          2  960100  Baker County
# 3                                47          1  960200  Baker County
# 4                                40          2  960200  Baker County
#
#   block_tract
# 0         NaN
# 1    1_960100
# 2    2_960100
# 3    1_960200
# 4    2_960200

# %%
owner_renter1['block_tract'] = owner_renter1['block'] + '_' + owner_renter1['tract']
owner_renter1.head()
# Out:
#                   GEO.id       GEO.id2         HD01_VD01  \
# 0                     Id           Id2  Estimate; Total:
# 1  1500000US130079601001  130079601001               869
# 2  1500000US130079601002  130079601002              1247
# 3  1500000US130079602001  130079602001               487
# 4  1500000US130079602002  130079602002               645
#
#                  HD02_VD01                          HD01_VD02  \
# 0  Margin of Error; Total:  Estimate; Total: - Owner occupied
# 1                      181                                457
# 2                      223                                764
# 3                      149                                386
# 4                      120                                489
#
#                                   HD02_VD02  \
# 0  Margin of Error; Total: - Owner occupied
# 1                                       159
# 2                                       170
# 3                                       133
# 4                                       120
#
#                             HD01_VD03  \
# 0  Estimate; Total: - Renter occupied
# 1                                 412
# 2                                 483
# 3                                 101
# 4                                 156
#
#                                    HD02_VD03      block   tract        county  \
# 0  Margin of Error; Total: - Renter occupied  Geography    None          None
# 1                                        154          1  960100  Baker County
# 2                                        210          2  960100  Baker County
# 3                                         74          1  960200  Baker County
# 4                                         91          2  960200  Baker County
#
#   block_tract
# 0         NaN
# 1    1_960100
# 2    2_960100
# 3    1_960200
# 4    2_960200

# %%
employment1['block_tract'] = employment1['block'] + '_' + employment1['tract']
employment1.head()
# Out:
#                   GEO.id       GEO.id2         HD01_VD01  \
# 0                     Id           Id2  Estimate; Total:
# 1  1500000US130079601001  130079601001               684
# 2  1500000US130079601002  130079601002              1038
# 3  1500000US130079602001  130079602001               450
# 4  1500000US130079602002  130079602002               507
#
#                  HD02_VD01                  HD01_VD02  \
# 0  Margin of Error; Total:  Estimate; In labor force:
# 1                      144                        350
# 2                      170                        488
# 3                      129                        262
# 4                       98                        219
#
#                           HD02_VD02  \
# 0  Margin of Error; In labor force:
# 1                               113
# 2                               124
# 3                               106
# 4                                69
#
#                                            HD01_VD03  \
# 0  Estimate; In labor force: - Civilian labor force:
# 1                                                350
# 2                                                488
# 3                                                262
# 4                                                219
#
#                                            HD02_VD03  \
# 0  Margin of Error; In labor force: - Civilian la...
# 1                                                113
# 2                                                124
# 3                                                106
# 4                                                 69
#
#                                            HD01_VD04  \
# 0  Estimate; In labor force: - Civilian labor for...
# 1                                                350
# 2                                                461
# 3                                                262
# 4                                                213
#
#                                            HD02_VD04  \
# 0  Margin of Error; In labor force: - Civilian la...
# 1                                                113
# 2                                                126
# 3                                                106
# 4                                                 69
#
#                                            HD01_VD05  \
# 0  Estimate; In labor force: - Civilian labor for...
# 1                                                  0
# 2                                                 27
# 3                                                  0
# 4                                                  6
#
#                                            HD02_VD05  \
# 0  Margin of Error; In labor force: - Civilian la...
# 1                                                 13
# 2                                                 22
# 3                                                 13
# 4                                                  9
#
#                                   HD01_VD06  \
# 0  Estimate; In labor force: - Armed Forces
# 1                                         0
# 2                                         0
# 3                                         0
# 4                                         0
#
#                                          HD02_VD06  \
# 0  Margin of Error; In labor force: - Armed Forces
# 1                                               13
# 2                                               13
# 3                                               13
# 4                                               13
#
#                       HD01_VD07                            HD02_VD07  \
# 0  Estimate; Not in labor force  Margin of Error; Not in labor force
# 1                           334                                   87
# 2                           550                                  156
# 3                           188                                   70
# 4                           288                                   81
#
#        block   tract        county block_tract
# 0  Geography    None          None         NaN
# 1          1  960100  Baker County    1_960100
# 2          2  960100  Baker County    2_960100
# 3          1  960200  Baker County    1_960200
# 4          2  960200  Baker County    2_960200

# %%
vacancy1.merge(vacancy1, on = "block_tract", how = "inner").shape
# Out:
# (112, 23)

# %%
owner_renter1.merge(owner_renter1, on = "block_tract", how = "inner").shape
# Out:
# (112, 23)

# %%
employment1.merge(employment1, on = "block_tract", how = "inner").shape
# Out:
# (112, 39)

# %%
vacancy1.to_csv('vacancy_final.csv', index = False)

# %%
owner_renter1.to_csv('owner_renter_final.csv', index = False)

# %%
employment1.to_csv('employment_final.csv', index = False)
