# %%
import pandas as pd

# %%
PATH = "/Users/william/Dropbox (Amherst College)/CDS-2019-AlbanyHub/"

# %%
df_tract = pd.read_csv(PATH + "ToDatabase/full_tract.csv")
df_blockgroup = pd.read_csv(PATH + "ToDatabase/full_blockgroup.csv")
df_junc = pd.read_csv(PATH + "ToDatabase/addr_junct_table.csv")

# %%
df_tract.head()
# Out:
#    tract       la_GEO.id  la_GEO.id2 la_GCT_STUB.target-geo-id  \
# 0    100  0500000US13095       13095      1400000US13095000100
# 1    200  0500000US13095       13095      1400000US13095000200
# 2    400  0500000US13095       13095      1400000US13095000400
# 3    501  0500000US13095       13095      1400000US13095000501
# 4    502  0500000US13095       13095      1400000US13095000502
#
#    la_GCT_STUB.target-geo-id2  tract_pop  tract_total_housingunits  \
# 0                 13095000100       5944                      2545
# 1                 13095000200       3123                      1348
# 2                 13095000400       6276                      3302
# 3                 13095000501       4798                      2365
# 4                 13095000502       4151                      1938
#
#    tract_totalarea  tract_totalarea_water  tract_totalarea_land  ...  \
# 0             3.17                   0.02                  3.15  ...
# ...

# %%
df_blockgroup.head()
# Out:
#                   geo_id       geo_id2  block_group   tract            county  \
# 0  1500000US130079601001  130079601001            1  960100      Baker County
# 1  1500000US130079601002  130079601002            2  960100      Baker County
# 2  1500000US130079602001  130079602001            1  960200      Baker County
# 3  1500000US130079602002  130079602002            2  960200      Baker County
# 4  1500000US130950001001  130950001001            1     100  Dougherty County
#
#   block_tract  total_pop  total_inc  inc_less_10k  inc_10k_14999  ...  \
# 0    1_960100        869        378            88             47  ...
# 1    2_960100       1247        426            88              7  ...
# 2    1_960200        487        224             0              7  ...
# 3    2_960200        648        293            55              0  ...
# 4       1_100        669        280             0              0  ...
#
# ...
