# %%
import pandas as pd

# %%
block = pd.read_csv("/Users/davidreynolds/Dropbox/CDS-2019-AlbanyHub/ToDatabase/full_blockgroup.csv")
address_counts = pd.read_csv("/Users/davidreynolds/Documents/CDS/Analysis/address_count_per_blockgroup.csv")
address_count_block = pd.read_csv("/Users/davidreynolds/Documents/CDS/Analysis/address_count_per_blockgroup_housingproject.csv")
avg_kwh = pd.read_csv("/Users/davidreynolds/Documents/CDS/Analysis/avgkwh_blockgroup_elec.csv")
avg_kwh_block = pd.read_csv("/Users/davidreynolds/Documents/CDS/Analysis/avg_kwh_per_blockgroup.csv")

# %%
df = (block[["total_vacdata", "block_group", "tract"]]).rename(columns = {"tract":"Tract","block_group":"BlockGroup"})

# %%
df_full = df.merge(address_counts, on = ["Tract", "BlockGroup"], how = "inner")
df_full = df_full.merge(address_count_block, on = ['Tract', "BlockGroup"], how = "left")
df_full = df_full.merge(avg_kwh, on = ['Tract', "BlockGroup"], how = "left")
df_full = df_full.merge(avg_kwh_block, on = ['Tract', "BlockGroup"], how = "left")

# %%
df_full = df_full.fillna(0)

# %%
df_full = df_full.rename(columns = {"address_count_x":"utilities_address_count", "address_count_y":"projects_address_count"})

# %%
df_full["nonproj_address_count"] = df_full["utilities_address_count"] - df_full["projects_address_count"]

# %%
df_full["proj_pct"] = df_full["projects_address_count"] / df_full["utilities_address_count"] * 100

# %%
df_full["nonproj_pct"] = 100 - df_full["proj_pct"]

# %%
df_full = df_full.drop("address_count", axis = 1)

# %%
df_full = df_full.rename(columns = {"mean_kwh":"project_mean_kwh", "avg_kwh":"nonproj_mean_kwh"}).drop("numrecords", axis = 1)

# %%
df_full = df_full.rename(columns = {"total_vacdata":"total_properties"})

# %%
cols = list(df_full)
cols.insert(0, cols.pop(cols.index('Tract')))
cols.insert(1, cols.pop(cols.index("BlockGroup")))
cols.insert(5, cols.pop(cols.index("nonproj_address_count")))
cols.insert(6, cols.pop(cols.index("proj_pct")))
cols.insert(7, cols.pop(cols.index("nonproj_pct")))
df_full = df_full.loc[:, cols]

# %%
sum_props = df_full["total_properties"].sum()
sum_utilities = df_full["utilities_address_count"].sum()
sum_projects = df_full["projects_address_count"].sum()
sum_nonproj = df_full["nonproj_address_count"].sum()

# %%
df_full = df_full.append({"total_properties" : sum_props, "utilities_address_count" : sum_utilities,
                         "projects_address_count" : sum_projects, "nonproj_address_count" : sum_nonproj}, ignore_index =  True)

# %%
df_full.loc[66, "Tract"] = "Totals"
df_full.loc[66, "proj_pct"] = sum_projects/sum_utilities*100
df_full.loc[66, "nonproj_pct"] = sum_nonproj/sum_utilities*100
df_full.loc[66, "project_mean_kwh"] = 798.2

# %%
df_full
# Out:
#      Tract  BlockGroup  total_properties  utilities_address_count  \
# 0      100         1.0             433.0                    193.0
# 1      100         2.0             175.0                    118.0
# 2      100         3.0             397.0                    344.0
# 3      100         4.0             938.0                    297.0
# 4      100         5.0             493.0                    247.0
# 5      200         1.0             352.0                    288.0
# 6      200         2.0             170.0                    175.0
# 7      200         3.0             560.0                    255.0
# 8      200         4.0             244.0                    173.0
# 9      400         1.0             738.0                    472.0
# 10     400         2.0            1027.0                    465.0
# 11     400         3.0            1542.0                    663.0
# 12     501         1.0            1476.0                    943.0
# 13     501         2.0             880.0                    171.0
# 14     502         1.0             668.0                    574.0
# 15     502         2.0             550.0                    515.0
# 16     502         3.0             237.0                    278.0
# 17     502         4.0             485.0                    372.0
# 18     600         1.0             713.0                    576.0
# 19     600         2.0             799.0                    548.0
# 20     700         1.0             933.0                    676.0
# 21     800         1.0             428.0                    372.0
# 22     800         2.0             298.0                    182.0
# 23     900         1.0             543.0                    388.0
# 24     900         2.0             551.0                    390.0
# 25    1000         1.0             323.0                    215.0
# 26    1000         2.0             701.0                    228.0
# 27    1100         1.0             559.0                    283.0
# 28    1100         2.0             468.0                    432.0
# 29    1100         3.0             303.0                    339.0
# ..     ...         ...               ...                      ...
# 37   10302         1.0             482.0                    278.0
# 38   10302         2.0             488.0                    200.0
# 39   10302         3.0             226.0                    274.0
# 40   10302         4.0             270.0                    269.0
# 41   10302         5.0             633.0                    477.0
# 42   10401         1.0             810.0                    281.0
# 43   10401         2.0            1045.0                    575.0
# 44   10401         3.0             819.0                    347.0
# 45   10402         1.0            1423.0                    707.0
# 46   10403         1.0             702.0                     16.0
# 47   10500         1.0             578.0                    310.0
# 48   10601         1.0             577.0                    340.0
# 49   10601         2.0             585.0                    357.0
# 50   10602         1.0             767.0                     11.0
# 51   10602         2.0             794.0                    363.0
# 52   10700         1.0             943.0                    502.0
# 53   10700         2.0             463.0                    435.0
# 54   10700         3.0             675.0                    287.0
# 55   10900         1.0             481.0                     97.0
# 56   10900         2.0             236.0                     45.0
# 57   10900         3.0              72.0                     60.0
# 58   11000         1.0             558.0                    177.0
# 59   11200         1.0             402.0                    149.0
# 60   11200         2.0             623.0                     32.0
# 61   11200         3.0             388.0                     59.0
# 62   11300         1.0            1227.0                    462.0
# 63   11400         1.0             427.0                    322.0
# 64   11400         2.0             181.0                    126.0
# 65   11600         1.0             649.0                     64.0
# 66  Totals         NaN           39548.0                  21485.0
#
#     projects_address_count  nonproj_address_count   proj_pct  nonproj_pct  \
# 0                     10.0                  183.0   5.181347    94.818653
# 1                      1.0                  117.0   0.847458    99.152542
# 2                      7.0                  337.0   2.034884    97.965116
# 3                      6.0                  291.0   2.020202    97.979798
# 4                      4.0                  243.0   1.619433    98.380567
# 5                     12.0                  276.0   4.166667    95.833333
# 6                      6.0                  169.0   3.428571    96.571429
# 7                     26.0                  229.0  10.196078    89.803922
# 8                      8.0                  165.0   4.624277    95.375723
# 9                      2.0                  470.0   0.423729    99.576271
# 10                     5.0                  460.0   1.075269    98.924731
# 11                     9.0                  654.0   1.357466    98.642534
# 12                     4.0                  939.0   0.424178    99.575822
# 13                     1.0                  170.0   0.584795    99.415205
# 14                     1.0                  573.0   0.174216    99.825784
# 15                     0.0                  515.0   0.000000   100.000000
# 16                     1.0                  277.0   0.359712    99.640288
# 17                     1.0                  371.0   0.268817    99.731183
# 18                     7.0                  569.0   1.215278    98.784722
# 19                     5.0                  543.0   0.912409    99.087591
# 20                     3.0                  673.0   0.443787    99.556213
# 21                     1.0                  371.0   0.268817    99.731183
# 22                     0.0                  182.0   0.000000   100.000000
# 23                     1.0                  387.0   0.257732    99.742268
# 24                     5.0                  385.0   1.282051    98.717949
# 25                     3.0                  212.0   1.395349    98.604651
# 26                    15.0                  213.0   6.578947    93.421053
# 27                     7.0                  276.0   2.473498    97.526502
# 28                    10.0                  422.0   2.314815    97.685185
# 29                    11.0                  328.0   3.244838    96.755162
# ..                     ...                    ...        ...          ...
# 37                    12.0                  266.0   4.316547    95.683453
# 38                     7.0                  193.0   3.500000    96.500000
# 39                    24.0                  250.0   8.759124    91.240876
# 40                     9.0                  260.0   3.345725    96.654275
# 41                    13.0                  464.0   2.725367    97.274633
# 42                     1.0                  280.0   0.355872    99.644128
# 43                     3.0                  572.0   0.521739    99.478261
# 44                     0.0                  347.0   0.000000   100.000000
# 45                    15.0                  692.0   2.121641    97.878359
# 46                     1.0                   15.0   6.250000    93.750000
# 47                     9.0                  301.0   2.903226    97.096774
# 48                    10.0                  330.0   2.941176    97.058824
# 49                    19.0                  338.0   5.322129    94.677871
# 50                     0.0                   11.0   0.000000   100.000000
# 51                    19.0                  344.0   5.234160    94.765840
# 52                    24.0                  478.0   4.780876    95.219124
# 53                    15.0                  420.0   3.448276    96.551724
# 54                     3.0                  284.0   1.045296    98.954704
# 55                     3.0                   94.0   3.092784    96.907216
# 56                     0.0                   45.0   0.000000   100.000000
# 57                     0.0                   60.0   0.000000   100.000000
# 58                     0.0                  177.0   0.000000   100.000000
# 59                     1.0                  148.0   0.671141    99.328859
# 60                     0.0                   32.0   0.000000   100.000000
# 61                     0.0                   59.0   0.000000   100.000000
# 62                     7.0                  455.0   1.515152    98.484848
# 63                    10.0                  312.0   3.105590    96.894410
# 64                     2.0                  124.0   1.587302    98.412698
# 65                     0.0                   64.0   0.000000   100.000000
# 66                   459.0                21026.0   2.136374    97.863626
#
#     project_mean_kwh  nonproj_mean_kwh
# 0         942.701170       1173.736357
# 1         750.361446       1000.101654
# 2         783.115846        917.290947
# 3         899.599131        878.535791
# 4        1301.032086       1135.678320
# 5         686.582310        874.904371
# 6        1144.103448       1040.032562
# 7         755.910126        918.039806
# 8         819.471429        790.358461
# 9         697.744071       1049.016942
# 10        753.223139        939.490938
# 11        819.027298        882.581342
# 12       1122.139932       1098.417853
# 13        911.409639       1749.343681
# 14       1144.090909       1319.904437
# 15          0.000000       1285.048657
# 16       1530.409639       1173.469978
# 17       1006.771084       1254.981498
# 18        777.257007       1060.767391
# 19        730.199837        920.442871
# 20       1156.347490       1015.764404
# 21        730.146199        713.668565
# 22          0.000000        912.446856
# 23       1080.493506       1045.772451
# 24       1036.455435        950.027106
# 25        784.756972       1071.965124
# 26        907.227543        833.970870
# 27       1058.883333       1032.775473
# 28        909.698944       1040.887727
# 29       1214.674276       1008.085524
# ..               ...               ...
# 37       1119.530120       1020.571646
# 38        864.413346        999.366288
# 39       1067.589540       1218.201713
# 40       1086.495943       1133.030345
# 41       1130.396078       1029.348931
# 42       1424.277108       1649.808522
# 43       1085.460829       1369.178937
# 44          0.000000       1537.903222
# 45        663.381110       1110.465938
# 46       1356.940079       1115.358845
# 47        908.926506       1144.015582
# 48        988.422842       1003.280542
# 49       1043.693658        981.293376
# 50          0.000000        532.617553
# 51        634.574176       1146.220741
# 52        895.790187       1161.855886
# 53       1106.878895        992.557910
# 54        999.995984       1072.337088
# 55       1114.489879       1316.513445
# 56          0.000000       1688.312266
# 57          0.000000       1166.159032
# 58          0.000000       1326.811250
# 59       1155.301205       1332.110469
# 60          0.000000       1178.082353
# 61          0.000000       1013.657049
# 62        872.472100        831.988067
# 63        856.327030        854.134578
# 64        763.086310        713.871078
# 65          0.000000       1523.580798
# 66        798.200000               NaN
#
# [67 rows x 10 columns]

# %%
df_full.to_csv('albany.csv', index =  False)
