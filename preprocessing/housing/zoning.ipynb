# %%
import pandas as pd

# %%
pd.options.display.max_columns = 60
pd.options.display.max_rows = 100

# %%
df = pd.read_excel('/Users/william/Dropbox (Amherst College)/CDS-2019-AlbanyHub/Raw-Data/ParceltoExcel.xls')

# %%
df.head()
# Out:
#    OBJECTID  AlbanyGIS.DBO.Parcel.AREA     Perimeter  Parcels  \
# 0         1               4.216727e+07  35935.189212      2.0
# 1         2               5.332497e+06  10475.873935      3.0
# 2         3               2.265748e+07  30013.889981      4.0
# 3         4               5.359983e+04    946.770341      5.0
# 4         5               9.015901e+06  12746.759157      6.0
#
#          ParcelNum                                      Name  Map_Code  \
# 0  00128/00001/002  WOOTEN GEORGIA H                               2.0
# 1  00128/00001/002  WOOTEN GEORGIA H                               2.0
# 2  00128/00001/001  WOOTEN STEVEN DULANEY                          2.0
# 3  00128/00001/01A  WOOTEN STEVEN DULANEY                          2.0
# 4  00128/00001/03N  BOOTH LARRY & BOOTH ERIC                       0.0
#
#   SplitFrom Exemption NonContig Section_ Phase Block         Zone_  District  \
# 0               S0                                    AG                 2.0
# ...

# %%
df['Zone_'].value_counts()
# Out:
# R1B             8748
# R1A             7911
# R3              7435
# R6              1955
# R1C             1852
# C3              1734
# AG              1354
#                 1140
# C2              1003
# C5               812
# R4               535
# R1               533
#                  474
# C1               471
# C7               448
# M1               426
# R4B              352
# R2               334
# R3               124
# FP               120
# R1                60
# C6                59
# C7                47
# R5                44
# C8                38
# M2                38
# R4A               33
# C4                20
# AG                19
# R1B               10
# C3                 8
# C2                 7
# C-2                6
# M1                 5
# C-R                5
# CR                 5
# RIA-C5             4
# R1A                4
# C1                 4
# R 1B               4
# R6                 4
# R-1                4
# R1C                3
# ...
